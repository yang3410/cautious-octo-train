# %%
import pandas as pd

# %%
ytdata = pd.read_csv("Final Result.csv")

# %%
ytdata
# Out:
#      Unnamed: 0                                   Video Link  \
# 0             0  https://www.youtube.com/watch?v=bWWTk-pZX5g
# 1             1  https://www.youtube.com/watch?v=gyK9USvrvDQ
# 2             2  https://www.youtube.com/watch?v=GihybX7JyG4
# 3             3  https://www.youtube.com/watch?v=4f2OCYaqLdE
# 4             4  https://www.youtube.com/watch?v=imA5NPX4ucU
# ..          ...                                          ...
# 510         510  https://www.youtube.com/watch?v=q-SdZe-cEFk
# 511         511  https://www.youtube.com/watch?v=dcHWmDQYzyU
# 512         512  https://www.youtube.com/watch?v=lbSOLBMUvIE
# 513         513  https://www.youtube.com/watch?v=ZmF8_g5H8fg
# 514         514  https://www.youtube.com/watch?v=Vr2FLgmWCJA
#
#                                            Video Title             Views  \
# 0    8 fiction books you need to read📚(& that will ...     382,446 views
# 1                 Top 10 BEST SELLING Books In History     575,824 views
# ...

# %%
print(ytdata.Comments[1])
# Out:
#  - Hello Aluxers, what's your favorite book series of all time Harry Potter or Lord of The Rings?
# What top 10 would you like to see next time?
# Join www.alux.com !
# 15 BOOKS TO READ THIS SUMMER: https://youtu.be/JRGhUCqDdcU
# Sanjay yadav - 10.The Da vinci code
# 9. She
# 8.The lion the witch and the wardrobe
# 7.The dream of the red chamber
# David Jepson - Typical. 10 secs of information presented in 20 plus mins.
# Studious Anjy - I hope one day I write a book that is on this list 😊
# Investing Hustler - My favourite book that changed my life and help me make a lot of money was rich dad poor dad !
# Ютуб25 - I've never heard about "she"
# Christopher Armstrong - Haven’t even started the video, but I’ll already bet the Bible is #1
# parth mehrotra - the alchemist is one of the best book
# Knowledge Bec - George Orwell’s 1984 is definitely a good read
# Ravi Kant - It's a good tactic to advertise your own book in the name of the top ten list.
# ...

# %%
ytdata = ytdata.loc[:,["Comments"]].copy()

# %%
ytdata.rename(columns = {'Comments':'YouTube'}, inplace = True)

# %%
ytdata
# Out:
#                                                YouTube
# 0    Yoo Se Na - "You know what sexy?....\r\nBooks....
# 1     - Hello Aluxers, what's your favorite book se...
# 2    Brian Perkins - I love audiobooks. I use youtu...
# 3    Ishaan Vohra - Watching a smart guy do smart t...
# 4    Sabine's Book Nook - Us both having a book buy...
# ..                                                 ...
# 510  XcuteR - Panda's daily routine -\r\nEating, ba...
# 511  Its Fawn - I wish you safety from Covid-19❤\r\...
# 512  Séries & Letras - so perfect\r\nKatsudon monst...
# 513                                                NaN
# 514   - BRUTAL! \r\n\r\nGuetta The Best ^^ \r\n\r\n...
#
# [515 rows x 1 columns]

# %%
ytdata = ytdata.dropna()

# %%
ytdata
# Out:
#                                                YouTube
# 0    Yoo Se Na - "You know what sexy?....\r\nBooks....
# 1     - Hello Aluxers, what's your favorite book se...
# 2    Brian Perkins - I love audiobooks. I use youtu...
# 3    Ishaan Vohra - Watching a smart guy do smart t...
# 4    Sabine's Book Nook - Us both having a book buy...
# ..                                                 ...
# 509   - Nice job!\r\n - 😊😢☺️😊😢☺️☺️😊😊😊☺️😊\r\nXX Sunn...
# 510  XcuteR - Panda's daily routine -\r\nEating, ba...
# 511  Its Fawn - I wish you safety from Covid-19❤\r\...
# 512  Séries & Letras - so perfect\r\nKatsudon monst...
# 514   - BRUTAL! \r\n\r\nGuetta The Best ^^ \r\n\r\n...
#
# [488 rows x 1 columns]

# %%
ytdata = ytdata.drop_duplicates().copy()

# %%
ytdata
# Out:
#                                                YouTube
# 0    Yoo Se Na - "You know what sexy?....\r\nBooks....
# 1     - Hello Aluxers, what's your favorite book se...
# 2    Brian Perkins - I love audiobooks. I use youtu...
# 3    Ishaan Vohra - Watching a smart guy do smart t...
# 4    Sabine's Book Nook - Us both having a book buy...
# ..                                                 ...
# 509   - Nice job!\r\n - 😊😢☺️😊😢☺️☺️😊😊😊☺️😊\r\nXX Sunn...
# 510  XcuteR - Panda's daily routine -\r\nEating, ba...
# 511  Its Fawn - I wish you safety from Covid-19❤\r\...
# 512  Séries & Letras - so perfect\r\nKatsudon monst...
# 514   - BRUTAL! \r\n\r\nGuetta The Best ^^ \r\n\r\n...
#
# [450 rows x 1 columns]

# %%
ytdata.reset_index(drop=True, inplace=True)

# %%
ytdata
# Out:
#                                                YouTube
# 0    Yoo Se Na - "You know what sexy?....\r\nBooks....
# 1     - Hello Aluxers, what's your favorite book se...
# 2    Brian Perkins - I love audiobooks. I use youtu...
# 3    Ishaan Vohra - Watching a smart guy do smart t...
# 4    Sabine's Book Nook - Us both having a book buy...
# ..                                                 ...
# 445   - Nice job!\r\n - 😊😢☺️😊😢☺️☺️😊😊😊☺️😊\r\nXX Sunn...
# 446  XcuteR - Panda's daily routine -\r\nEating, ba...
# 447  Its Fawn - I wish you safety from Covid-19❤\r\...
# 448  Séries & Letras - so perfect\r\nKatsudon monst...
# 449   - BRUTAL! \r\n\r\nGuetta The Best ^^ \r\n\r\n...
#
# [450 rows x 1 columns]

# %% [markdown]
# I used this webpage: https://perchance.org/youtube-video to generate 100 random YouTube videos. This was the output:

# %%
#https://www.youtube.com/watch?v=fHf2WoBVc-U
#https://www.youtube.com/watch?v=_TVFkp39s2I
#https://www.youtube.com/watch?v=ZYKc7Zpr5OI
#https://www.youtube.com/watch?v=fEXkADXvUe0
#https://www.youtube.com/watch?v=QMCxbIWKDFY
#https://www.youtube.com/watch?v=1TUIgCHDJFg
#https://www.youtube.com/watch?v=RRzoYUavPD0
#https://www.youtube.com/watch?v=0f4nARtyFiY
#https://www.youtube.com/watch?v=7cy4IJnfho4
#https://www.youtube.com/watch?v=DAZYhnmQXow
#https://www.youtube.com/watch?v=9tOEmu5VDzc
#https://www.youtube.com/watch?v=fKr4Sz2AmUU
#https://www.youtube.com/watch?v=1i8AHCZrJUk
#https://www.youtube.com/watch?v=K28q5mk3euE
#https://www.youtube.com/watch?v=BKLZT66P68A
#https://www.youtube.com/watch?v=m-RHp516sU0
#https://www.youtube.com/watch?v=NVNleUnd5wo
#https://www.youtube.com/watch?v=dQw4w9WgXcQ
#https://www.youtube.com/watch?v=mBcoS3jFlWI
#https://www.youtube.com/watch?v=5pU6gr46NHI
#https://www.youtube.com/watch?v=BNlBt3hmvDk
#https://www.youtube.com/watch?v=Xzrf7xhUo2g
#https://www.youtube.com/watch?v=s95cxZkC_es
#https://www.youtube.com/watch?v=L6hm2JPVhOU
#https://www.youtube.com/watch?v=5uvCLA7ekO4
#https://www.youtube.com/watch?v=rBuPeoFx-04
#https://www.youtube.com/watch?v=Zj372ZWXAJw
#https://www.youtube.com/watch?v=83ccyVvQJ00
#https://www.youtube.com/watch?v=0y8oc-UE3bw
#https://www.youtube.com/watch?v=_i0E65hzW2M
#https://www.youtube.com/watch?v=8U7ZocUeWDk
#https://www.youtube.com/watch?v=U96ojO8s8oE
#https://www.youtube.com/watch?v=nHbSBjuoVE4
#https://www.youtube.com/watch?v=n4ka3A2EAKM
#https://www.youtube.com/watch?v=vMLk_T0PPbk
#https://www.youtube.com/watch?v=nPVgkZhZLQ4
#https://www.youtube.com/watch?v=qUZIzYwmEDE
#https://www.youtube.com/watch?v=nc34-sfjHb8
#https://www.youtube.com/watch?v=iS68LmqFVeA
#https://www.youtube.com/watch?v=gFHZ1CSABHs

#These are saved in the file "100randomytvideos.csv".

# %% [markdown]
# Now I use PIP to install a YouTube comment scrapper:
#
# pip install https://github.com/egbertbouman/youtube-comment-downloader/archive/master.zip

# %%
ytvideos = pd.read_csv("100randomytvideos.csv")
ytvideos
# Out:
#                                           Video
# 0   https://www.youtube.com/watch?v=fHf2WoBVc-U
# 1   https://www.youtube.com/watch?v=_TVFkp39s2I
# 2   https://www.youtube.com/watch?v=ZYKc7Zpr5OI
# 3   https://www.youtube.com/watch?v=fEXkADXvUe0
# 4   https://www.youtube.com/watch?v=QMCxbIWKDFY
# ..                                          ...
# 95  https://www.youtube.com/watch?v=nPVgkZhZLQ4
# 96  https://www.youtube.com/watch?v=qUZIzYwmEDE
# 97  https://www.youtube.com/watch?v=nc34-sfjHb8
# 98  https://www.youtube.com/watch?v=iS68LmqFVeA
# 99  https://www.youtube.com/watch?v=gFHZ1CSABHs
#
# [100 rows x 1 columns]

# %% [markdown]
# Now I use the comment scrapper to produce 100 data files with comments on them: for each video, I will extract 300 random comments from them, or all of them in case they have less than 300.

# %%
from itertools import islice
from youtube_comment_downloader import *
downloader = YoutubeCommentDownloader()

# %%
for i in range(100):
    comments = downloader.get_comments_from_url(ytvideos.Video[i])
    for comment in islice(comments, 350):
        ytdata.loc[len(ytdata)] = [comment["text"]]

# %%
ytdata
# Out:
#                                                  YouTube
# 0      Yoo Se Na - "You know what sexy?....\r\nBooks....
# 1       - Hello Aluxers, what's your favorite book se...
# 2      Brian Perkins - I love audiobooks. I use youtu...
# 3      Ishaan Vohra - Watching a smart guy do smart t...
# 4      Sabine's Book Nook - Us both having a book buy...
# ...                                                  ...
# 12196                               Best contestant ever
# 12197                                       9:16 is gold
# 12198  Wait, did she said her cat came back from the ...
# 12199  Ok we all have to admit it. Aubrey turns us on...
# 12200  She is so boring. If she was my my girlfriend ...
#
# [12201 rows x 1 columns]

# %% [markdown]
# Let us now clean the data again:

# %%
ytdata = ytdata.dropna()
ytdata = ytdata.drop_duplicates()
ytdata.reset_index(drop=True, inplace=True)
ytdata
# Out:
#                                                  YouTube
# 0      Yoo Se Na - "You know what sexy?....\r\nBooks....
# 1       - Hello Aluxers, what's your favorite book se...
# 2      Brian Perkins - I love audiobooks. I use youtu...
# 3      Ishaan Vohra - Watching a smart guy do smart t...
# 4      Sabine's Book Nook - Us both having a book buy...
# ...                                                  ...
# 11750                               Best contestant ever
# 11751                                       9:16 is gold
# 11752  Wait, did she said her cat came back from the ...
# 11753  Ok we all have to admit it. Aubrey turns us on...
# 11754  She is so boring. If she was my my girlfriend ...
#
# [11755 rows x 1 columns]

# %% [markdown]
# Finally, we create the data file.

# %%
ytdata.to_csv('ytdata.csv', index=False)
