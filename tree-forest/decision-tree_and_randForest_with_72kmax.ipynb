# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
X_train = pd.read_csv('../max72k_data/max72k_X_train.csv')
X_test = pd.read_csv('../max72k_data/max72k_X_test.csv')
y_train = pd.read_csv('../max72k_data/max72k_y_train.csv')
y_test = pd.read_csv('../max72k_data/max72k_y_test.csv')

# %%
X_train.head()
# Out:
#    Unnamed: 0  positive_words  negative_words  length  word_count  male_words
# 0      170363               8              12    1516         286           0  \
# 1      129380               0               1      65          12           0
# 2       50679               0               0      25           3           0
# 3      166490               1               0     101          19           0
# 4       83020               0               0      21           5           0
#
#    female_words  afinn  intensity  positivity
# 0             0    1.0   0.069930   -0.013986
# 1             0    2.0   0.083333   -0.083333
# 2             0    0.0   0.000000    0.000000
# 3             0   -2.0   0.052632    0.052632
# 4             0    0.0   0.000000    0.000000

# %%
X_train
# Out:
#         Unnamed: 0  positive_words  negative_words  length  word_count
# 0           170363               8              12    1516         286  \
# 1           129380               0               1      65          12
# 2            50679               0               0      25           3
# 3           166490               1               0     101          19
# 4            83020               0               0      21           5
# ...            ...             ...             ...     ...         ...
# 136867       90705               0               2      91          17
# 136868      145513               0               1      17           2
# 136869       70075               0               1      84          16
# 136870       86506               0               0      42           7
# 136871       40447               0               0      34           7
#
#         male_words  female_words  afinn  intensity  positivity
# ...

# %%
X_test
# Out:
#        Unnamed: 0  positive_words  negative_words  length  word_count
# 0           90391               1               0      43           7  \
# 1          149903               0               0      59          11
# 2          161451               5               0      93          17
# 3          120108               0               0      55          12
# 4           79069               1               0     107          17
# ...           ...             ...             ...     ...         ...
# 34214       12231               2               0     107          25
# 34215       93272               0               0      60          13
# 34216      158391               0               0      15           3
# 34217      101551               1               0      40           7
# 34218      147997               0               0      65          13
#
#        male_words  female_words  afinn  intensity  positivity
# 0               0             0    3.0   0.142857    0.142857
# ...

# %%
y_train
# Out:
#         Unnamed: 0   platform
# 0           170363    youtube
# 1           129380     reddit
# 2            50679    twitter
# 3           166490    youtube
# 4            83020  instagram
# ...            ...        ...
# 136867       90705     reddit
# 136868      145513     reddit
# 136869       70075    twitter
# 136870       86506  instagram
# 136871       40447    twitter
#
# [136872 rows x 2 columns]

# %%
y_test
# Out:
#        Unnamed: 0  positive_words  negative_words  length  word_count
# 0           90391               1               0      43           7  \
# 1          149903               0               0      59          11
# 2          161451               5               0      93          17
# 3          120108               0               0      55          12
# 4           79069               1               0     107          17
# ...           ...             ...             ...     ...         ...
# 34214       12231               2               0     107          25
# 34215       93272               0               0      60          13
# 34216      158391               0               0      15           3
# 34217      101551               1               0      40           7
# 34218      147997               0               0      65          13
#
#        male_words  female_words  afinn  intensity  positivity
# 0               0             0    3.0   0.142857    0.142857
# ...

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
model = DecisionTreeClassifier(max_depth = 10, random_state = 42)

# %%
model.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 model.fit(X_train, y_train)
#
# File ~/micromamba/lib/python3.11/site-packages/sklearn/tree/_classes.py:889, in DecisionTreeClassifier.fit(self, X, y, sample_weight, check_input)
#     859 def fit(self, X, y, sample_weight=None, check_input=True):
#     860     """Build a decision tree classifier from the training set (X, y).
#     861
#     862     Parameters
#    (...)
#     886         Fitted estimator.
#     887     """
# --> 889     super().fit(
#     890         X,
#     891         y,
#     892         sample_weight=sample_weight,
#     893         check_input=check_input,
#     894     )
#     895     return self
#
# File ~/micromamba/lib/python3.11/site-packages/sklearn/tree/_classes.py:186, in BaseDecisionTree.fit(self, X, y, sample_weight, check_input)
# ...

# %% [markdown]
# Let's get rid of NaN terms

# %%
df = pd.read_csv('../max72k_data/max72kpost_data.csv')

# %%
df
# Out:
#         Unnamed: 0                                               text
# 0                0            Had a good first days WE at the herald   \
# 1                1                  whaat. making sure.. she's safe.
# 2                2                          HAHAHAHAHAHA, Se ferrou!
# 3                3           Cant sleep with bad thoughts in my mind
# 4                4  so tired and sick of trains, tho getting on an...
# ...            ...                                                ...
# 171086      587253                               Best contestant ever
# 171087      587254                                       9:16 is gold
# 171088      587255  Wait, did she said her cat came back from the ...
# 171089      587256  Ok we all have to admit it. Aubrey turns us on...
# 171090      587257  She is so boring. If she was my my girlfriend ...
#
#        platform  positive_words  negative_words  length  word_count
# ...

# %%
df.dropna()
# Out:
#         Unnamed: 0                                               text
# 0                0            Had a good first days WE at the herald   \
# 1                1                  whaat. making sure.. she's safe.
# 2                2                          HAHAHAHAHAHA, Se ferrou!
# 3                3           Cant sleep with bad thoughts in my mind
# 4                4  so tired and sick of trains, tho getting on an...
# ...            ...                                                ...
# 171086      587253                               Best contestant ever
# 171087      587254                                       9:16 is gold
# 171088      587255  Wait, did she said her cat came back from the ...
# 171089      587256  Ok we all have to admit it. Aubrey turns us on...
# 171090      587257  She is so boring. If she was my my girlfriend ...
#
#        platform  positive_words  negative_words  length  word_count
# ...

# %%
df
# Out:
#         Unnamed: 0                                               text
# 0                0            Had a good first days WE at the herald   \
# 1                1                  whaat. making sure.. she's safe.
# 2                2                          HAHAHAHAHAHA, Se ferrou!
# 3                3           Cant sleep with bad thoughts in my mind
# 4                4  so tired and sick of trains, tho getting on an...
# ...            ...                                                ...
# 171086      587253                               Best contestant ever
# 171087      587254                                       9:16 is gold
# 171088      587255  Wait, did she said her cat came back from the ...
# 171089      587256  Ok we all have to admit it. Aubrey turns us on...
# 171090      587257  She is so boring. If she was my my girlfriend ...
#
#        platform  positive_words  negative_words  length  word_count
# ...

# %%
df = df.dropna()

# %%
df
# Out:
#         Unnamed: 0                                               text
# 0                0            Had a good first days WE at the herald   \
# 1                1                  whaat. making sure.. she's safe.
# 2                2                          HAHAHAHAHAHA, Se ferrou!
# 3                3           Cant sleep with bad thoughts in my mind
# 4                4  so tired and sick of trains, tho getting on an...
# ...            ...                                                ...
# 171086      587253                               Best contestant ever
# 171087      587254                                       9:16 is gold
# 171088      587255  Wait, did she said her cat came back from the ...
# 171089      587256  Ok we all have to admit it. Aubrey turns us on...
# 171090      587257  She is so boring. If she was my my girlfriend ...
#
#        platform  positive_words  negative_words  length  word_count
# ...

# %%
y = df['platform']

# %%
X = df[['positive_words', 'negative_words', 'length', 'word_count', 'male_words', 'female_words', 'afinn', 'intensity', 'positivity']]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test=train_test_split(X,y, stratify=y, random_state=42, test_size=0.2)

# %%
model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=10, random_state=42)

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %%
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# [[  207  2302   411    89]
#  [   55 12346  1992    34]
#  [   51  7821  6508    20]
#  [  103  1493   439   226]]
#               precision    recall  f1-score   support
#
#    instagram       0.50      0.07      0.12      3009
#       reddit       0.52      0.86      0.64     14427
#      twitter       0.70      0.45      0.55     14400
#      youtube       0.61      0.10      0.17      2261
#
#     accuracy                           0.57     34097
#    macro avg       0.58      0.37      0.37     34097
# weighted avg       0.60      0.57      0.53     34097

# %%
from sklearn import tree

# %%
plt.figure(figsize = (6,6))
tree.plot_tree(model, filled = True)
plt.show()

# %%
feature_importance = sorted(zip(model.feature_importances_, X_train.columns), key=(lambda x:x[0]), reverse=True)
print("Importance of features:")
for pair in feature_importance:
    print(pair)
# Out:
# Importance of features:
# (0.8169733022013299, 'length')
# (0.06501972454933376, 'word_count')
# (0.06446597477441603, 'afinn')
# (0.020649629982696496, 'positivity')
# (0.010565569809390144, 'intensity')
# (0.008102485926175705, 'female_words')
# (0.006109168509735856, 'male_words')
# (0.006025769286212039, 'negative_words')
# (0.002088374960710075, 'positive_words')

# %%
model2 = DecisionTreeClassifier(max_depth = 3, random_state = 42)

# %%
model2.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=3, random_state=42)

# %%
y_pred2 = model2.predict(X_test)

# %%
print(confusion_matrix(y_test, y_pred2))
print(classification_report(y_test, y_pred2))
# Out:
# [[  137  2485   295    92]
#  [    8 12498  1892    29]
#  [    2  8365  6026     7]
#  [   86  1573   390   212]]
#               precision    recall  f1-score   support
#
#    instagram       0.59      0.05      0.08      3009
#       reddit       0.50      0.87      0.64     14427
#      twitter       0.70      0.42      0.52     14400
#      youtube       0.62      0.09      0.16      2261
#
#     accuracy                           0.55     34097
#    macro avg       0.60      0.36      0.35     34097
# weighted avg       0.60      0.55      0.51     34097

# %%
plt.figure(figsize = (20,20))
tree.plot_tree(model2, filled = True)
plt.show()

# %%
feature_importance = sorted(zip(model2.feature_importances_, X_train.columns), key=(lambda x:x[0]), reverse=True)
print("Importance of features:")
for pair in feature_importance:
    print(pair)
# Out:
# Importance of features:
# (0.9538585535198688, 'length')
# (0.03301423281656339, 'afinn')
# (0.013127213663567784, 'positivity')
# (0.0, 'positive_words')
# (0.0, 'negative_words')
# (0.0, 'word_count')
# (0.0, 'male_words')
# (0.0, 'female_words')
# (0.0, 'intensity')

# %%
model2.classes_
# Out:
# array(['instagram', 'reddit', 'twitter', 'youtube'], dtype=object)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier()
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred_rf = rf.predict(X_test)

# %%
print(confusion_matrix(y_test, y_pred_rf))
print(classification_report(y_test, y_pred_rf))
# Out:
# [[  321  1961   622   105]
#  [  316 10125  3816   170]
#  [  250  6281  7658   211]
#  [  133  1242   623   263]]
#               precision    recall  f1-score   support
#
#    instagram       0.31      0.11      0.16      3009
#       reddit       0.52      0.70      0.59     14427
#      twitter       0.60      0.53      0.56     14400
#      youtube       0.35      0.12      0.17      2261
#
#     accuracy                           0.54     34097
#    macro avg       0.45      0.36      0.37     34097
# weighted avg       0.52      0.54      0.52     34097
