# %%
import pandas as pd

# %%
data = pd.read_csv("full_dataset.csv")

# %%
data
# Out:
#         Unnamed: 0                                               text  \
# 0                0            Had a good first days WE at the herald
# 1                1                  whaat. making sure.. she's safe.
# 2                2                          HAHAHAHAHAHA, Se ferrou!
# 3                3           Cant sleep with bad thoughts in my mind
# 4                4  so tired and sick of trains, tho getting on an...
# ...            ...                                                ...
# 587253      587253                               Best contestant ever
# 587254      587254                                       9:16 is gold
# 587255      587255  Wait, did she said her cat came back from the ...
# 587256      587256  Ok we all have to admit it. Aubrey turns us on...
# 587257      587257  She is so boring. If she was my my girlfriend ...
#
#        platform  positive_words  negative_words  length  word_count  \
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
fig,axes = plt.subplots(2,2,figsize=(8,12))


axes[0,0].scatter(data.loc[data.platform=="twitter"].female_words,data.loc[data.platform=="twitter"].positive_words)
axes[0,0].set_xlabel("Female words", fontsize=10)
axes[0,0].set_ylabel("Positive words", fontsize=10)
axes[0,0].set_title("Twitter", fontsize=12)


axes[0,1].scatter(data.loc[data.platform=="instagram"].female_words,data.loc[data.platform=="instagram"].positive_words)
axes[0,1].set_xlabel("Female words", fontsize=10)
axes[0,1].set_ylabel("Positive words", fontsize=10)
axes[0,1].set_title("Instagram", fontsize=12)

axes[1,0].scatter(data.loc[data.platform=="reddit"].female_words,data.loc[data.platform=="reddit"].positive_words)
axes[1,0].set_xlabel("Female words", fontsize=10)
axes[1,0].set_ylabel("Positive words", fontsize=10)
axes[1,0].set_title("Reddit", fontsize=12)



axes[1,1].scatter(data.loc[data.platform=="youtube"].female_words,data.loc[data.platform=="youtube"].positive_words)
axes[1,1].set_xlabel("Female words", fontsize=10)
axes[1,1].set_ylabel("Positive words", fontsize=10)
axes[1,1].set_title("YouTube", fontsize=12)




plt.show()

# %%
fig,axes = plt.subplots(2,2,figsize=(8,12))


axes[0,0].scatter(data.loc[data.platform=="twitter"].male_words,data.loc[data.platform=="twitter"].positive_words)
axes[0,0].set_xlabel("Male words", fontsize=10)
axes[0,0].set_ylabel("Positive words", fontsize=10)
axes[0,0].set_title("Twitter", fontsize=12)


axes[0,1].scatter(data.loc[data.platform=="instagram"].male_words,data.loc[data.platform=="instagram"].positive_words)
axes[0,1].set_xlabel("Male words", fontsize=10)
axes[0,1].set_ylabel("Positive words", fontsize=10)
axes[0,1].set_title("Instagram", fontsize=12)

axes[1,0].scatter(data.loc[data.platform=="reddit"].male_words,data.loc[data.platform=="reddit"].positive_words)
axes[1,0].set_xlabel("Male words", fontsize=10)
axes[1,0].set_ylabel("Positive words", fontsize=10)
axes[1,0].set_title("Reddit", fontsize=12)



axes[1,1].scatter(data.loc[data.platform=="youtube"].male_words,data.loc[data.platform=="youtube"].positive_words)
axes[1,1].set_xlabel("Male words", fontsize=10)
axes[1,1].set_ylabel("Positive words", fontsize=10)
axes[1,1].set_title("YouTube", fontsize=12)




plt.show()

# %%
fig,axes = plt.subplots(2,2,figsize=(8,12))


axes[0,0].scatter(data.loc[data.platform=="twitter"].male_words,data.loc[data.platform=="twitter"].negative_words)
axes[0,0].set_xlabel("Male words", fontsize=10)
axes[0,0].set_ylabel("Negative words", fontsize=10)
axes[0,0].set_title("Twitter", fontsize=12)


axes[0,1].scatter(data.loc[data.platform=="instagram"].male_words,data.loc[data.platform=="instagram"].negative_words)
axes[0,1].set_xlabel("Male words", fontsize=10)
axes[0,1].set_ylabel("Negative words", fontsize=10)
axes[0,1].set_title("Instagram", fontsize=12)

axes[1,0].scatter(data.loc[data.platform=="reddit"].male_words,data.loc[data.platform=="reddit"].negative_words)
axes[1,0].set_xlabel("Male words", fontsize=10)
axes[1,0].set_ylabel("Negative words", fontsize=10)
axes[1,0].set_title("Reddit", fontsize=12)



axes[1,1].scatter(data.loc[data.platform=="youtube"].male_words,data.loc[data.platform=="youtube"].negative_words)
axes[1,1].set_xlabel("Male words", fontsize=10)
axes[1,1].set_ylabel("Negative words", fontsize=10)
axes[1,1].set_title("YouTube", fontsize=12)




plt.show()

# %%
fig,axes = plt.subplots(2,2,figsize=(8,12))


axes[0,0].scatter(data.loc[data.platform=="twitter"].female_words,data.loc[data.platform=="twitter"].negative_words)
axes[0,0].set_xlabel("Female words", fontsize=10)
axes[0,0].set_ylabel("Negative words", fontsize=10)
axes[0,0].set_title("Twitter", fontsize=12)


axes[0,1].scatter(data.loc[data.platform=="instagram"].female_words,data.loc[data.platform=="instagram"].negative_words)
axes[0,1].set_xlabel("Female words", fontsize=10)
axes[0,1].set_ylabel("Negative words", fontsize=10)
axes[0,1].set_title("Instagram", fontsize=12)

axes[1,0].scatter(data.loc[data.platform=="reddit"].female_words,data.loc[data.platform=="reddit"].negative_words)
axes[1,0].set_xlabel("Female words", fontsize=10)
axes[1,0].set_ylabel("Negative words", fontsize=10)
axes[1,0].set_title("Reddit", fontsize=12)



axes[1,1].scatter(data.loc[data.platform=="youtube"].female_words,data.loc[data.platform=="youtube"].negative_words)
axes[1,1].set_xlabel("Female words", fontsize=10)
axes[1,1].set_ylabel("Negative words", fontsize=10)
axes[1,1].set_title("YouTube", fontsize=12)




plt.show()

# %% [markdown]
# Let us pick one: Male words vs Positive words. This seems to yield a clear feature that distinguishes Instagram from the rest of social media.

# %%
fig,axes = plt.subplots(2,2,figsize=(20,20))


axes[0,0].scatter(data.loc[data.platform=="twitter"].male_words,data.loc[data.platform=="twitter"].positive_words)
axes[0,0].set_xlabel("Male words", fontsize=10)
axes[0,0].set_ylabel("Positive words", fontsize=10)
axes[0,0].set_title("Twitter", fontsize=12)


axes[0,1].scatter(data.loc[data.platform=="instagram"].male_words,data.loc[data.platform=="instagram"].positive_words)
axes[0,1].set_xlabel("Male words", fontsize=10)
axes[0,1].set_ylabel("Positive words", fontsize=10)
axes[0,1].set_title("Instagram", fontsize=12)

axes[1,0].scatter(data.loc[data.platform=="reddit"].male_words,data.loc[data.platform=="reddit"].positive_words)
axes[1,0].set_xlabel("Male words", fontsize=10)
axes[1,0].set_ylabel("Positive words", fontsize=10)
axes[1,0].set_title("Reddit", fontsize=12)



axes[1,1].scatter(data.loc[data.platform=="youtube"].male_words,data.loc[data.platform=="youtube"].positive_words)
axes[1,1].set_xlabel("Male words", fontsize=10)
axes[1,1].set_ylabel("Positive words", fontsize=10)
axes[1,1].set_title("YouTube", fontsize=12)




plt.show()

# %%
print("INSTAGRAM")
print()
data2=data.loc[data.platform=="instagram"]
data3=data2.loc[0<data.positive_words]
data4=data3.loc[data.positive_words>=0]
data5=data4.loc[data.male_words>=0]
data6=data5.loc[data.positive_words>=0]
print(str(len(data2.loc[0<data.positive_words])/len(data2))+" of the posts have positive words")
print(str(len(data2.loc[0<data.male_words])/len(data2))+" of the posts have male words")
print(str(len(data2.loc[0<data.negative_words])/len(data2))+" of the posts have negative words")
print(str(len(data2.loc[0<data.female_words])/len(data2))+" of the posts have female words")
print()
print(str(len(data2.loc[data.male_words<data.positive_words])/len(data2))+" of the posts have more positive words than male words")
print(str(len(data2.loc[data.male_words<data.female_words])/len(data2))+" of the posts have more female words than male words")
print(str(len(data2.loc[data.female_words<data.male_words])/len(data2))+" of the posts have more male words than female words")
print(str(len(data2.loc[data.female_words<data.negative_words])/len(data2))+" of the posts have more negative words than female words")


print()
print(str(len(data2.loc[15<data.word_count])/len(data2))+" of the posts have more than 15 words")





del data2
del data3
del data4
del data5
del data6
# Out:
# INSTAGRAM
#
# 0.32475083056478404 of the posts have positive words
# 0.057053411704574494 of the posts have male words
# 0.11589573217480194 of the posts have negative words
# 0.04925888065422949 of the posts have female words
#
# 0.30692563250702787 of the posts have more positive words than male words
# 0.04542550472783031 of the posts have more female words than male words
# 0.05168668540761564 of the posts have more male words than female words
# 0.10675951955021723 of the posts have more negative words than female words
#
# 0.14892665474060823 of the posts have more than 15 words

# %%
print("TWITTER")
print()
data2=data.loc[data.platform=="twitter"]
data3=data2.loc[0<data.positive_words]
data4=data3.loc[data.positive_words>=0]
data5=data4.loc[data.male_words>=0]
data6=data5.loc[data.positive_words>=0]
print(str(len(data2.loc[0<data.positive_words])/len(data2))+" of the posts have positive words")
print(str(len(data2.loc[0<data.male_words])/len(data2))+" of the posts have male words")
print(str(len(data2.loc[0<data.negative_words])/len(data2))+" of the posts have negative words")
print(str(len(data2.loc[0<data.female_words])/len(data2))+" of the posts have female words")
print()
print(str(len(data2.loc[data.male_words<data.positive_words])/len(data2))+" of the posts have more positive words than male words")
print(str(len(data2.loc[data.male_words<data.female_words])/len(data2))+" of the posts have more female words than male words")
print(str(len(data2.loc[data.female_words<data.male_words])/len(data2))+" of the posts have more male words than female words")
print(str(len(data2.loc[data.female_words<data.negative_words])/len(data2))+" of the posts have more negative words than female words")


print()
print(str(len(data2.loc[15<data.word_count])/len(data2))+" of the posts have more than 15 words")





del data2
del data3
del data4
del data5
del data6
# Out:
# TWITTER
#
# 0.351101160053834 of the posts have positive words
# 0.059807401975143754 of the posts have male words
# 0.2770896025335592 of the posts have negative words
# 0.040393963541165215 of the posts have female words
#
# 0.32935450368419006 of the posts have more positive words than male words
# 0.0361659022424703 of the posts have more female words than male words
# 0.05502625126237538 of the posts have more male words than female words
# 0.26495441109292517 of the posts have more negative words than female words
#
# 0.33704859197774534 of the posts have more than 15 words

# %%
print("REDDIT")
print()
data2=data.loc[data.platform=="reddit"]
data3=data2.loc[0<data.positive_words]
data4=data3.loc[data.positive_words>=0]
data5=data4.loc[data.male_words>=0]
data6=data5.loc[data.positive_words>=0]
print(str(len(data2.loc[0<data.positive_words])/len(data2))+" of the posts have positive words")
print(str(len(data2.loc[0<data.male_words])/len(data2))+" of the posts have male words")
print(str(len(data2.loc[0<data.negative_words])/len(data2))+" of the posts have negative words")
print(str(len(data2.loc[0<data.female_words])/len(data2))+" of the posts have female words")
print()
print(str(len(data2.loc[data.male_words<data.positive_words])/len(data2))+" of the posts have more positive words than male words")
print(str(len(data2.loc[data.male_words<data.female_words])/len(data2))+" of the posts have more female words than male words")
print(str(len(data2.loc[data.female_words<data.male_words])/len(data2))+" of the posts have more male words than female words")
print(str(len(data2.loc[data.female_words<data.negative_words])/len(data2))+" of the posts have more negative words than female words")


print()
print(str(len(data2.loc[15<data.word_count])/len(data2))+" of the posts have more than 15 words")





del data2
del data3
del data4
del data5
del data6
# Out:
# REDDIT
#
# 0.29612532057946905 of the posts have positive words
# 0.040424204616344356 of the posts have male words
# 0.16326332570874055 of the posts have negative words
# 0.021944964303042904 of the posts have female words
#
# 0.2838705205517433 of the posts have more positive words than male words
# 0.01921397379912664 of the posts have more female words than male words
# 0.037166424065987386 of the posts have more male words than female words
# 0.15913218271296875 of the posts have more negative words than female words
#
# 0.10429056629929992 of the posts have more than 15 words

# %%
print("YOUTUBE")
print()
data2=data.loc[data.platform=="youtube"]
data3=data2.loc[0<data.positive_words]
data4=data3.loc[data.positive_words>=0]
data5=data4.loc[data.male_words>=0]
data6=data5.loc[data.positive_words>=0]
print(str(len(data2.loc[0<data.positive_words])/len(data2))+" of the posts have positive words")
print(str(len(data2.loc[0<data.male_words])/len(data2))+" of the posts have male words")
print(str(len(data2.loc[0<data.negative_words])/len(data2))+" of the posts have negative words")
print(str(len(data2.loc[0<data.female_words])/len(data2))+" of the posts have female words")
print()
print(str(len(data2.loc[data.male_words<data.positive_words])/len(data2))+" of the posts have more positive words than male words")
print(str(len(data2.loc[data.male_words<data.female_words])/len(data2))+" of the posts have more female words than male words")
print(str(len(data2.loc[data.female_words<data.male_words])/len(data2))+" of the posts have more male words than female words")
print(str(len(data2.loc[data.female_words<data.negative_words])/len(data2))+" of the posts have more negative words than female words")


print()
print(str(len(data2.loc[15<data.word_count])/len(data2))+" of the posts have more than 15 words")





del data2
del data3
del data4
del data5
del data6
# Out:
# YOUTUBE
#
# 0.3634111818825195 of the posts have positive words
# 0.08819886765746639 of the posts have male words
# 0.23389950460014156 of the posts have negative words
# 0.03529723991507431 of the posts have female words
#
# 0.331829440905874 of the posts have more positive words than male words
# 0.030520169851380043 of the posts have more female words than male words
# 0.08200636942675159 of the posts have more male words than female words
# 0.22496461429582448 of the posts have more negative words than female words
#
# 0.2592887473460722 of the posts have more than 15 words
